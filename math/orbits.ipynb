# %%
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# !pip install mplcyberpunk
# !pip install pyvista pyvistaqt trame
# !pip install "pyvista[jupyter]"
# !pip install vispy ipywidgets
# !pip install plotly
# Out:
# Requirement already satisfied: numpy in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (2.3.5)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mplcyberpunk in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (0.7.6)
# Requirement already satisfied: matplotlib in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from mplcyberpunk) (3.10.7)
# Requirement already satisfied: numpy>1.24.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from mplcyberpunk) (2.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib->mplcyberpunk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplcyberpunk) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyvista in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (0.47.1)
# Requirement already satisfied: pyvistaqt in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (0.11.3)
# Requirement already satisfied: trame in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (3.12.0)
# Requirement already satisfied: cyclopts>=4.0.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (4.7.0)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (3.10.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (2.3.5)
# Requirement already satisfied: pillow in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (12.0.0)
# Requirement already satisfied: pooch in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (1.9.0)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (4.15.0)
# Requirement already satisfied: vtk!=9.4.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista) (9.6.0)
# Requirement already satisfied: QtPy>=1.9.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvistaqt) (2.4.3)
# Requirement already satisfied: trame-server<4,>=3.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame) (3.10.0)
# Requirement already satisfied: trame-client<4,>=3.10.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame) (3.11.3)
# Requirement already satisfied: trame-common<2,>=1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame) (1.1.2)
# Requirement already satisfied: wslink>=2.3.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame) (2.5.5)
# Requirement already satisfied: pyyaml in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame) (6.0.3)
# Requirement already satisfied: more-itertools in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame-server<4,>=3.4->trame) (10.8.0)
# Requirement already satisfied: aiohttp<4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from wslink>=2.3.3->trame) (3.13.3)
# Requirement already satisfied: msgpack<2,>=1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from wslink>=2.3.3->trame) (1.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (1.23.0)
# Requirement already satisfied: idna>=2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4->wslink>=2.3.3->trame) (3.11)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cyclopts>=4.0.0->pyvista) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cyclopts>=4.0.0->pyvista) (1.3.2)
# Requirement already satisfied: rich>=13.6.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cyclopts>=4.0.0->pyvista) (14.3.3)
# Requirement already satisfied: docutils in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->pyvista) (0.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->cyclopts>=4.0.0->pyvista) (0.1.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pooch->pyvista) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pooch->pyvista) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from requests>=2.19.0->pooch->pyvista) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from requests>=2.19.0->pooch->pyvista) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from requests>=2.19.0->pooch->pyvista) (2025.11.12)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyvista[jupyter] in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (0.47.1)
# Requirement already satisfied: cyclopts>=4.0.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (4.7.0)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (3.10.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (2.3.5)
# Requirement already satisfied: pillow in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (12.0.0)
# Requirement already satisfied: pooch in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (1.9.0)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (4.15.0)
# Requirement already satisfied: vtk!=9.4.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (9.6.0)
# Requirement already satisfied: ipywidgets in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (8.1.8)
# Requirement already satisfied: jupyter-server-proxy in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (4.4.0)
# Requirement already satisfied: nest-asyncio2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (1.7.2)
# Requirement already satisfied: trame-client>=2.12.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (3.11.3)
# Requirement already satisfied: trame-server!=3.7.*,!=3.8.0,>=2.11.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (3.10.0)
# Requirement already satisfied: trame-vtk!=2.10.3,!=2.11.* in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (2.10.2)
# Requirement already satisfied: trame-vuetify>=2.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (3.2.1)
# Requirement already satisfied: trame>=2.5.2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pyvista[jupyter]) (3.12.0)
# Requirement already satisfied: trame-common>=0.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame-client>=2.12.7->pyvista[jupyter]) (1.1.2)
# Requirement already satisfied: attrs>=23.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cyclopts>=4.0.0->pyvista[jupyter]) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cyclopts>=4.0.0->pyvista[jupyter]) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cyclopts>=4.0.0->pyvista[jupyter]) (1.3.2)
# Requirement already satisfied: rich>=13.6.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cyclopts>=4.0.0->pyvista[jupyter]) (14.3.3)
# Requirement already satisfied: docutils in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->pyvista[jupyter]) (0.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista[jupyter]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista[jupyter]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista[jupyter]) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista[jupyter]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista[jupyter]) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista[jupyter]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib>=3.0.1->pyvista[jupyter]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista[jupyter]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista[jupyter]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista[jupyter]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->cyclopts>=4.0.0->pyvista[jupyter]) (0.1.2)
# Requirement already satisfied: wslink>=2.3.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame>=2.5.2->pyvista[jupyter]) (2.5.5)
# Requirement already satisfied: pyyaml in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame>=2.5.2->pyvista[jupyter]) (6.0.3)
# Requirement already satisfied: more-itertools in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from trame-server!=3.7.*,!=3.8.0,>=2.11.7->pyvista[jupyter]) (10.8.0)
# Requirement already satisfied: aiohttp<4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (3.13.3)
# Requirement already satisfied: msgpack<2,>=1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (1.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from aiohttp<4->wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (1.23.0)
# Requirement already satisfied: idna>=2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4->wslink>=2.3.3->trame>=2.5.2->pyvista[jupyter]) (3.11)
# Requirement already satisfied: comm>=0.1.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets->pyvista[jupyter]) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets->pyvista[jupyter]) (9.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets->pyvista[jupyter]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets->pyvista[jupyter]) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets->pyvista[jupyter]) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->pyvista[jupyter]) (0.2.3)
# Requirement already satisfied: jupyter-server>=1.24.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server-proxy->pyvista[jupyter]) (2.17.0)
# Requirement already satisfied: simpervisor>=1.0.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server-proxy->pyvista[jupyter]) (1.0.0)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server-proxy->pyvista[jupyter]) (6.5.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (4.12.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jinja2>=3.0.3->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (4.5.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (4.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (4.0.0)
# Requirement already satisfied: referencing in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.37.0)
# Requirement already satisfied: rfc3339-validator in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.30.0)
# Requirement already satisfied: fqdn in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0b1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[jupyter]) (2025.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from pooch->pyvista[jupyter]) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from requests>=2.19.0->pooch->pyvista[jupyter]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from requests>=2.19.0->pooch->pyvista[jupyter]) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from requests>=2.19.0->pooch->pyvista[jupyter]) (2025.11.12)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: vispy in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (0.16.1)
# Requirement already satisfied: ipywidgets in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (8.1.8)
# Requirement already satisfied: numpy in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from vispy) (2.3.5)
# Requirement already satisfied: freetype-py in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from vispy) (2.5.1)
# Requirement already satisfied: hsluv in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from vispy) (5.0.4)
# Requirement already satisfied: kiwisolver in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from vispy) (1.4.9)
# Requirement already satisfied: packaging in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from vispy) (25.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets) (9.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (6.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from plotly) (2.17.0)
# Requirement already satisfied: packaging in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from plotly) (25.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")

import mplcyberpunk

plt.style.use("cyberpunk")

# %%
# %matplotlib notebook

# %% [markdown]
# ### Тестовый график

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

fig, ax = plt.subplots()

x = np.linspace(0, 10, 100)
line, = ax.plot(x, np.sin(x))


def update(frame):
    line.set_ydata(np.sin(x + frame * 0.1))
    return line,


ani = FuncAnimation(fig, update, frames=200, interval=50)

plt.show()
# Out:
# <div id='16ca9ff3-0fc0-45f5-a2a1-956cfff2a3b7'></div>

# %% [markdown]
# # График движения по орбите

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.widgets import Slider

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.subplots_adjust(bottom=0.35)

# параметры орбиты
a = 5
e = 0.4
inclination = 20

# центр орбиты
cx = 0
cy = 0
cz = 0

t = np.linspace(0, 2 * np.pi, 200)


def orbit(a, e, inc, cx, cy, cz):
    r = a * (1 - e ** 2) / (1 + e * np.cos(t))

    x = r * np.cos(t)
    y = r * np.sin(t)
    z = np.zeros_like(t)

    # наклон
    inc = np.radians(inc)
    z = y * np.sin(inc)
    y = y * np.cos(inc)

    # смещение центра
    x = x + cx
    y = y + cy
    z = z + cz

    return x, y, z


x, y, z = orbit(a, e, inclination, cx, cy, cz)

line, = ax.plot(x, y, z)
planet, = ax.plot([x[0]], [y[0]], [z[0]], 'o')

ax.set_xlim(-20, 20)
ax.set_ylim(-20, 20)
ax.set_zlim(-20, 20)

# -------- sliders --------

ax_a = plt.axes((0.2, 0.25, 0.65, 0.03))
ax_e = plt.axes((0.2, 0.20, 0.65, 0.03))
ax_i = plt.axes((0.2, 0.15, 0.65, 0.03))
ax_speed = plt.axes((0.2, 0.10, 0.65, 0.03))

ax_cx = plt.axes((0.2, 0.05, 0.65, 0.03))
ax_cy = plt.axes((0.2, 0.00, 0.65, 0.03))

slider_a = Slider(ax_a, "a", 1, 10, valinit=a)
slider_e = Slider(ax_e, "e", 0, 0.9, valinit=e)
slider_i = Slider(ax_i, "incl", 0, 90, valinit=inclination)
slider_speed = Slider(ax_speed, "speed", 0.1, 10, valinit=1)

slider_cx = Slider(ax_cx, "center x", -10, 10, valinit=0)
slider_cy = Slider(ax_cy, "center y", -10, 10, valinit=0)


def update(frame):
    a = slider_a.val
    e = slider_e.val
    inc = slider_i.val
    speed = slider_speed.val

    cx = slider_cx.val
    cy = slider_cy.val
    cz = 0

    x, y, z = orbit(a, e, inc, cx, cy, cz)

    line.set_data(x, y)
    line.set_3d_properties(z)

    idx = int(frame * speed) % len(x)

    planet.set_data([x[idx]], [y[idx]])
    planet.set_3d_properties([z[idx]])

    return line, planet


anim = FuncAnimation(fig, update, frames=len(t), interval=40)

plt.show()
# Out:
# <div id='09cb8475-ec19-4c14-9a2b-5b4e30128235'></div>

# %% [markdown]
# # Вращения спутника вокруг планеты

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.widgets import Slider
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.subplots_adjust(bottom=0.40)

# параметры
a = 5
e = 0.4
inclination = 20

a_moon = 1.5
incl_moon = 30

theta_planet = 0
theta_moon = 0

# центр
cx = 0
cy = 0

t = np.linspace(0, 2 * np.pi, 300)


def orbit_curve(a, e, inc):
    r = a * (1 - e ** 2) / (1 + e * np.cos(t))

    x = r * np.cos(t)
    y = r * np.sin(t)
    z = np.zeros_like(x)

    inc = np.radians(inc)

    z = y * np.sin(inc)
    y = y * np.cos(inc)

    return x, y, z


def orbit_point(a, e, inc, theta):
    r = a * (1 - e ** 2) / (1 + e * np.cos(theta))

    x = r * np.cos(theta)
    y = r * np.sin(theta)
    z = 0

    inc = np.radians(inc)

    z = y * np.sin(inc)
    y = y * np.cos(inc)

    return x, y, z


x, y, z = orbit_curve(a, e, inclination)

line, = ax.plot(x, y, z)
planet, = ax.plot([x[0]], [y[0]], [z[0]], 'o')

moon_orbit_line, = ax.plot([], [], [])
moon, = ax.plot([], [], [], 'o')

ax.set_xlim(-20, 20)
ax.set_ylim(-20, 20)
ax.set_zlim(-20, 20)

# sliders

ax_a = plt.axes((0.2, 0.30, 0.65, 0.03))
ax_speed = plt.axes((0.2, 0.25, 0.65, 0.03))
ax_moon = plt.axes((0.2, 0.20, 0.65, 0.03))
ax_cx = plt.axes((0.2, 0.15, 0.65, 0.03))
ax_cy = plt.axes((0.2, 0.10, 0.65, 0.03))

slider_a = Slider(ax_a, "planet orbit", 1, 10, valinit=a)
slider_speed = Slider(ax_speed, "speed", 0.1, 10, valinit=1)
slider_moon = Slider(ax_moon, "moon orbit", 0.2, 5, valinit=a_moon)

slider_cx = Slider(ax_cx, "center x", -10, 10, valinit=0)
slider_cy = Slider(ax_cy, "center y", -10, 10, valinit=0)


def update(frame):
    global theta_planet, theta_moon

    a = slider_a.val
    speed = slider_speed.val
    a_moon = slider_moon.val

    cx = slider_cx.val
    cy = slider_cy.val

    theta_planet += 0.02 * speed
    theta_moon += 0.08 * speed

    # обновляем орбиту планеты
    x, y, z = orbit_curve(a, e, inclination)
    x += cx
    y += cy

    line.set_data(x, y)
    line.set_3d_properties(z)

    # позиция планеты
    px, py, pz = orbit_point(a, e, inclination, theta_planet)

    px += cx
    py += cy

    planet.set_data([px], [py])
    planet.set_3d_properties([pz])

    # орбита луны
    mx, my, mz = orbit_curve(a_moon, 0, incl_moon)

    mx += px
    my += py
    mz += pz

    moon_orbit_line.set_data(mx, my)
    moon_orbit_line.set_3d_properties(mz)

    # позиция луны
    mx, my, mz = orbit_point(a_moon, 0, incl_moon, theta_moon)

    mx += px
    my += py
    mz += pz

    moon.set_data([mx], [my])
    moon.set_3d_properties([mz])

    return line, planet, moon, moon_orbit_line


ani = FuncAnimation(
    fig,
    update,
    interval=40,
    cache_frame_data=False
)

plt.show()
# Out:
# <div id='9350010a-2fe2-4425-a232-bb7238b3eff2'></div>
# C:\Users\SyperOlao\CLionProjects\QuickSort\.venv\Lib\site-packages\matplotlib\animation.py:908: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

fig = plt.figure()
ax = fig.add_subplot(111)

a = 10
e = 0.6

theta = 0

line1, = ax.plot([], [], 'r')
line2, = ax.plot([], [], 'r')

star1, = ax.plot([], [], 'wo', markersize=10)
star2, = ax.plot([], [], 'wo', markersize=10)

bary, = ax.plot([0], [0], 'r+')

t = np.linspace(0, 2 * np.pi, 400)


def orbit_curve():
    r = a * (1 - e ** 2) / (1 + e * np.cos(t))

    x = r * np.cos(t)
    y = r * np.sin(t)

    return x, y


x, y = orbit_curve()

line1.set_data(-x / 2, -y / 2)
line2.set_data(x / 2, y / 2)

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)


def update(frame):
    global theta

    theta += 0.03

    r = a * (1 - e ** 2) / (1 + e * np.cos(theta))

    x = r * np.cos(theta)
    y = r * np.sin(theta)

    x1 = -x / 2
    y1 = -y / 2

    x2 = x / 2
    y2 = y / 2

    star1.set_data([x1], [y1])
    star2.set_data([x2], [y2])

    return star1, star2


ani = FuncAnimation(fig, update, interval=40)

plt.show()
# Out:
# <div id='6383b30a-f946-46d5-9430-b596d049ca1d'></div>
# C:\Users\SyperOlao\AppData\Local\Temp\ipykernel_28248\2489059293.py:66: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(fig, update, interval=40)

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.widgets import Slider
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.subplots_adjust(bottom=0.25)

# параметры
a = 10
e = 0.6
incl = 30

theta = 0

# точки
star1, = ax.plot([], [], [], 'wo', markersize=10)
star2, = ax.plot([], [], [], 'wo', markersize=10)

orbit1, = ax.plot([], [], [], 'r')
orbit2, = ax.plot([], [], [], 'r')

bary, = ax.plot([0], [0], [0], 'r+')

t = np.linspace(0, 2 * np.pi, 400)


def orbit_curve(a, e, inc):
    r = a * (1 - e ** 2) / (1 + e * np.cos(t))

    x = r * np.cos(t)
    y = r * np.sin(t)
    z = np.zeros_like(x)

    inc = np.radians(inc)

    z = y * np.sin(inc)
    y = y * np.cos(inc)

    return x, y, z


x, y, z = orbit_curve(a, e, incl)

orbit1.set_data(-x / 2, -y / 2)
orbit1.set_3d_properties(-z / 2)

orbit2.set_data(x / 2, y / 2)
orbit2.set_3d_properties(z / 2)

ax.set_xlim(-20, 20)
ax.set_ylim(-20, 20)
ax.set_zlim(-20, 20)

# sliders

ax_speed = plt.axes((0.2, 0.1, 0.65, 0.03))
ax_a = plt.axes((0.2, 0.05, 0.65, 0.03))

slider_speed = Slider(ax_speed, "speed", 0.1, 5, valinit=1)
slider_a = Slider(ax_a, "orbit size", 5, 20, valinit=a)


def update(frame):
    global theta

    speed = slider_speed.val
    a = slider_a.val

    theta += 0.02 * speed

    r = a * (1 - e ** 2) / (1 + e * np.cos(theta))

    x = r * np.cos(theta)
    y = r * np.sin(theta)
    z = 0

    inc_r = np.radians(incl)

    z = y * np.sin(inc_r)
    y = y * np.cos(inc_r)

    x1, y1, z1 = -x / 2, -y / 2, -z / 2
    x2, y2, z2 = x / 2, y / 2, z / 2

    star1.set_data([x1], [y1])
    star1.set_3d_properties([z1])

    star2.set_data([x2], [y2])
    star2.set_3d_properties([z2])

    x, y, z = orbit_curve(a, e, incl)

    orbit1.set_data(-x / 2, -y / 2)
    orbit1.set_3d_properties(-z / 2)

    orbit2.set_data(x / 2, y / 2)
    orbit2.set_3d_properties(z / 2)

    return star1, star2, orbit1, orbit2


ani = FuncAnimation(fig, update, interval=40, cache_frame_data=False)

plt.show()
# Out:
# <div id='ce9e26f0-b0c0-4a48-9e0b-7745d63631aa'></div>

# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (0.10.0)
# Requirement already satisfied: ipython<10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipympl) (9.8.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipympl) (8.1.8)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipympl) (3.10.7)
# Requirement already satisfied: numpy in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipympl) (2.3.5)
# Requirement already satisfied: pillow in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipympl) (12.0.0)
# Requirement already satisfied: traitlets<6 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from jedi>=0.18.1->ipython<10->ipympl) (0.8.5)
# Requirement already satisfied: six>=1.5 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\syperolao\clionprojects\quicksort\.venv\lib\site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (0.2.3)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider

fig = plt.figure(figsize=(9, 7))
ax = fig.add_subplot(111, projection='3d')
plt.subplots_adjust(bottom=0.25)

a_bin = 16.0
e_bin = 0.4
incl_deg = 20.0

a_planet = 35.0
e_planet = 0.15


def solve_kepler(M, e, tol=1e-10, max_iter=30):
    M = np.mod(M, 2 * np.pi)
    E = M if e < 0.8 else np.pi

    for _ in range(max_iter):
        f = E - e * np.sin(E) - M
        fp = 1 - e * np.cos(E)
        dE = -f / fp
        E += dE
        if abs(dE) < tol:
            break
    return E


def kepler_position(a, e, inc_deg, M):
    E = solve_kepler(M, e)

    x_orb = a * (np.cos(E) - e)
    y_orb = a * np.sqrt(1 - e ** 2) * np.sin(E)

    inc = np.radians(inc_deg)
    x = x_orb
    y = y_orb * np.cos(inc)
    z = y_orb * np.sin(inc)

    return x, y, z


def build_orbit_curve(a, e, inc_deg, num=400):
    E_vals = np.linspace(0, 2 * np.pi, num)
    x_orb = a * (np.cos(E_vals) - e)
    y_orb = a * np.sqrt(1 - e ** 2) * np.sin(E_vals)

    inc = np.radians(inc_deg)
    x = x_orb
    y = y_orb * np.cos(inc)
    z = y_orb * np.sin(inc)

    return x, y, z


# линии орбит
xs, ys, zs = build_orbit_curve(a_bin / 2, e_bin, incl_deg)
xp, yp, zp = build_orbit_curve(a_planet, e_planet, incl_deg)

ax.plot(xs, ys, zs, 'y--', linewidth=1)
ax.plot(-xs, -ys, -zs, 'y--', linewidth=1)
ax.plot(xp, yp, zp, 'b--', linewidth=1)

# объекты
star1, = ax.plot([0], [0], [0], 'yo', markersize=10)
star2, = ax.plot([0], [0], [0], 'yo', markersize=10)
planet, = ax.plot([0], [0], [0], 'bo', markersize=6)
ax.plot([0], [0], [0], 'r+', markersize=10)

ax.set_xlim(-50, 50)
ax.set_ylim(-50, 50)
ax.set_zlim(-50, 50)

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.view_init(elev=25, azim=35)

# слайдеры
ax_time = plt.axes((0.2, 0.10, 0.65, 0.03))
ax_planet_a = plt.axes((0.2, 0.05, 0.65, 0.03))

slider_time = Slider(ax_time, "time", 0.0, 100.0, valinit=0.0)
slider_planet_a = Slider(ax_planet_a, "planet orbit", 25.0, 80.0, valinit=a_planet)


def redraw(val):
    t = slider_time.val
    planet_a = slider_planet_a.val

    # звезды
    x1, y1, z1 = kepler_position(a_bin / 2, e_bin, incl_deg, t * 0.8)
    x2, y2, z2 = -x1, -y1, -z1

    star1.set_data([x1], [y1])
    star1.set_3d_properties([z1])

    star2.set_data([x2], [y2])
    star2.set_3d_properties([z2])

    # планета
    px, py, pz = kepler_position(planet_a, e_planet, incl_deg, t * 0.22)
    planet.set_data([px], [py])
    planet.set_3d_properties([pz])

    fig.canvas.draw_idle()


slider_time.on_changed(redraw)
slider_planet_a.on_changed(redraw)

redraw(0)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
